# %% [markdown]
# # Data Module - Dataset and DataLoader

# %% [markdown]
# ## 1. Environment Setup

# %%
print(1)

# !pip install torch torchvision pillow wandb gradio pyyaml pytorch

## import torch
import sys

print(f"Python: {sys.version}")
print(f"PyTorch: {torch.__version__}")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'Not Found'}")

import torch

# This MUST return True for your project to run efficiently
print(f"Is GPU available? {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"Total VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    print("STILL ON CPU: Please check the sidebar settings again.")

# %% [markdown]
# ## 2. Dataset Importing

# %% [markdown]
# ### A. Data Description and Shape

# %%
# load Libraries

import pandas as pd

# %%
# loading the kaggle datasets

df = pd.read_csv('/kaggle/input/datasets/hiteshsuthar101/myntra-fashion-product-dataset/Fashion Dataset.csv')
df.sample(5)
# Out:
#        Unnamed: 0        p_id  \
# 809           809  17911130.0
# 12217         387  15962194.0
# 6257          317  16758930.0
# 5594          644  18067038.0
# 10906          66  14191746.0
#
#                                                     name   price    colour  \
# 809    Indo Era Women Burgundy Sequined Kurta with Pa...  3499.0  Burgundy
# 12217        MANGO Women Olive Green Solid Padded Jacket  5590.0     Olive
# 6257   ZIYAA Women Classic White Printed Mandarin Col...  3733.0     White
# 5594          BUY NEW TREND Blue Flared Knitted Palazzos  1399.0      Blue
# 10906            WEAVERS VILLA Black Embroidered Dupatta   799.0     Black
#
#                brand                                                img  \
# 809         Indo Era  http://assets.myntassets.com/assets/images/179...
# 12217          MANGO  http://assets.myntassets.com/assets/images/159...
# 6257           ZIYAA  http://assets.myntassets.com/assets/images/167...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'p_id', 'name', 'price', 'colour', 'brand', 'img',
#        'ratingCount', 'avg_rating', 'description', 'p_attributes'],
#       dtype='object')

# %%
df.shape
# Out:
# (14330, 11)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0        p_id  \
# 0               0  17048614.0
# 1               1  16524740.0
# 2               2  16331376.0
# 3               3  14709966.0
# 4               4  11056154.0
# ...           ...         ...
# 14325         985  15415116.0
# 14326         986  16470114.0
# 14327         987  16382150.0
# 14328         988  16379664.0
# 14329         989  16379656.0
#
#                                                     name   price     colour  \
# 0      Khushal K Women Black Ethnic Motifs Printed Ku...  5099.0      Black
# 1      InWeave Women Orange Solid Kurta with Palazzos...  5899.0     Orange
# 2      Anubhutee Women Navy Blue Ethnic Motifs Embroi...  4899.0  Navy Blue
# 3      Nayo Women Red Floral Printed Kurta With Trous...  3699.0        Red
# 4       AHIKA Women Black & Green Printed Straight Kurta  1350.0      Black
# ...                                                  ...     ...        ...
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# p_id            float64
# name             object
# price           float64
# colour           object
# brand            object
# img              object
# ratingCount     float64
# avg_rating      float64
# description      object
# p_attributes     object
# dtype: object

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of        Unnamed: 0   p_id   name  price  colour  brand    img  ratingCount  \
# 0           False  False  False  False   False  False  False        False
# 1           False  False  False  False   False  False  False        False
# 2           False  False  False  False   False  False  False        False
# 3           False  False  False  False   False  False  False        False
# 4           False  False  False  False   False  False  False        False
# ...           ...    ...    ...    ...     ...    ...    ...          ...
# 14325       False  False  False  False   False  False  False        False
# 14326       False  False  False  False   False  False  False         True
# 14327       False  False  False  False   False  False  False         True
# 14328       False  False  False  False   False  False  False         True
# 14329       False  False  False  False   False  False  False         True
#
#        avg_rating  description  p_attributes
# ...
