# %% [markdown]
# # Data Module - Dataset and DataLoader

# %% [markdown]
# ## 1. Environment Setup

# %%
print(1)
# Out:
# 1

# %%
# !pip install torch torchvision pillow wandb gradio pyyaml

# %%
conda install pytorch==2.0.1 torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - defaults
#  - conda-forge
# Platform: osx-64
# ...
# Solving environment: failed
#
# LibMambaUnsatisfiableError: Encountered problems while solving:
#   - nothing provides cuda 11.8.* needed by pytorch-cuda-11.8-h8dd9ede_2
#
# Could not solve for environment specs
# The following package could not be installed
# └─ pytorch-cuda 11.8**  is not installable because it requires
#    └─ cuda 11.8.* , which does not exist (perhaps a missing channel).
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch

import torch
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("MPS device found. Using Apple Silicon GPU.")
else:
    device = torch.device("cpu")
    print("MPS not found. Using CPU.")

# Example: Move your model to the Mac GPU
# model.to(device)
# Out:
# 4045.15s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.
# MPS device found. Using Apple Silicon GPU.
